# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddharth5723/python_for_ml/blob/main/OOPS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Car:
  def __init__(self,make,model,year):
    self.make = make
    self.model = model
    self.year = year

car = Car("Audi" , "German" , 1996)
print(car.make)
# Out:
# Audi

# %%
class Car:
  def __init__(self,make,model,year):
    self.make = make
    self.model = model
    self.year = year
  def start_engine(self):
    print(f"{self.make} enigne has started")
car = Car("Audi" , "German" , 1996)
print(car.make)
car.start_engine()
# Out:
# Audi
# Audi enigne has started

# %%
class Student:
  def __init__(self,name,age):
    self.name = name
    self.age = age

student = Student("Siddharth" , 21)
student.name
# Out:
# 'Siddharth'

# %%
class BankAccount:
  def __init__(self,account_number,balance):
    self.__account_number = account_number
    self.__balance = balance

  def Deposit(self , amount):
    self.__balance += amount

  def withdraw(self , amount):
    if amount > self.__balance:
      print("insufficent balance")
    else:
      self.__balance -= amount

  def check(self):
    return self.__balance



bck = BankAccount('12345' , 1000)
bck.Deposit(500)
bck.withdraw(200)
print(bck.check())
bck.withdraw(2000)
# Out:
# 1300
# insufficent balance

# %%
#base class
class Person:
  def __init__(self,name,age):
    self.name = name
    self.age = age

#Derived class
class Employee(Person):
  def __init__(self,name,age,employee_id):
    super().__init__(name,age)
    self.employee_id = employee_id

  def __str__(self):
    return f"{self.name} is {self.age} years old and the employee_id : {self.employee_id}"


employee = Employee("Siddharth", 21 , "E123")
print(employee)
# Out:
# Siddharth is 21 years old and the employee_id : E123

# %%
class Address:
  def __init__(self,street,city,zipcode):
    self.street = street
    self.city = city
    self.zipcode =  zipcode

class Person(Address):
  def __init__(self,name,age,street,city,zipcode):
    super().__init__(street,city,zipcode)
    self.name = name
    self.age = age

  def __str__(self):
    return f"{self.name},age: {self.age} lives in {self.street} ,{self.city}, zipcode : {self.zipcode}"

person = Person("Siddharth" , 21 , "wall street" , "New York", 302021)
print(person)
# Out:
# Siddharth,age: 21 lives in wall street ,New York, zipcode : 302021

# %%
class Counter:
  count = 0

  def __init__(self):
    Counter.count += 1

  @classmethod
  def get_count(cls):
    return cls.count


c1 = Counter()
c2 = Counter()
c3 = Counter()
print(Counter.get_count())
# Out:
# 3

# %%
import math

class MathOperations:
  @staticmethod
  def sqrt(x):
    return math.sqrt(x)

print(MathOperations.sqrt(16))
# Out:
# 4.0

# %%
class Rectangle:
  def __init__(self,length,width):
    self.__length = length
    self.__width = width

  def get_length(self):
    return self.__length

  def set_length(self,length):
    self.__length = length

  def get_width(self):
    return self.__width

  def set_width(self,width):
    self.__width = width

rect = Rectangle(10,5)
print(rect.get_length() , rect.get_width())
rect.set_length(15)
print(rect.get_length())
# Out:
# 10 5
# 15

# %%
from abc import ABC , abstractmethod

class Shape(ABC):
  @abstractmethod
  def area(self):
    pass

class Circle(Shape):
  def __init__(self, radius):
    self.radius = radius

  def area(self):
    return math.pi * self.radius ** 2

class Square(Shape):
  def __init__(self, side):
    self.side = side

  def area(self):
    return self.side ** 2


circle = Circle(5)
square = Square(4)
print(circle.area())
# Out:
# 78.53981633974483

# %%
class Vector:
  def __init__(self, x , y):
    self.x = x
    self.y = y

  def __add__(self, other):
    return Vector(self.x + other.x , self.y + other.y)

  def __str__(self):
    return f"Vector({self.x}  , {self.y})"


v1 = Vector(2,3)
v2 = Vector(4,5)
v3 = v1 + v2
print(v3)
# Out:
# Vector(6  , 8)

# %%
class InsufficientBalanceError(Exception):
  pass

class BankAccount:
  def __init__(self,account_number,balance):
    self.__account_number = account_number
    self.__balance = balance

  def Deposit(self , amount):
    self.__balance += amount

  def withdraw(self , amount):
    amount = int(input("Enter the amount to withdraw : "))
    if amount > self.__balance:
      raise InsufficientBalanceError("Insufficient balance")
    else:
      self.__balance -= amount

  def check(self):
    return self.__balance


amount = BankAccount("12345" , 2000)
amount.Deposit(300)
try:
  amount.withdraw(amount)
except InsufficientBalanceError as e:
  print(f"Error : {e}")
# Out:
# Enter the amount to withdraw : 6000
# Error : Insufficient balance

# %%
class Animal:
  def __init__(self,name,species):
    self.name = name
    self.species = species

class Dog(Animal):
  def __init__(self,name,species,breed):
    super().__init__(name , species)
    self.breed = breed


dog = Dog("Buddy" , "mammal" , "labrador")
print(dog.name ,dog.species , dog.breed)
# Out:
# Buddy mammal labrador

# %%
class Animal:
  def __init__(self,name,species):
    self.name = name
    self.species = species

class Dog(Animal):
  def __init__(self,name,species,breed):
    super().__init__(name , species)
    self.breed = breed

  def __str__(self):
    return f"{self.name} is a {self.species} species that come under {self.breed} breed"




dog = Dog("Buddy" , "mammal" , "labrador")
print(dog)
# Out:
# Buddy is a mammal species that come under labrador breed

# %%
class Animal:
  def __init__(self,name,species):
    self.name = name
    self.species = species

class Dog(Animal):
  def __init__(self,name,species,breed):
    super().__init__(name , species)
    self.breed = breed

  def bark(self):
    return f"{self.name} says woof!!"

  def __str__(self):
    return f"{self.name} comes under {self.species} and he is a {self.breed} breed"

dog = Dog("Buddy" , "mammal" , "labrador")
print(dog)
print(dog.bark())
# Out:
# Buddy comes under mammal and he is a labrador breed
# Buddy says woof!!

# %%
class Walker:
  def walk(self):
    print("Walking.....")

class Runner:
  def run(self):
    print("Running......")


class Athlete(Walker , Runner):
  pass


athlete = Athlete()
athlete.walk()
athlete.run()
# Out:
# Walking.....
# Running......

# %%
class Walker:
  def walk(self):
    print("Walking.....")

class Runner:
  def run(self):
    print("Running......")


#class Athlete(Walker , Runner):
  #def walk(self):
 #   print("Athlete walking...")
    #super().walk()


#athlete = Athlete()
#athlete.walk()

# %%
class Walker:
  def walk(self):
    print("Walking.....")

class Runner:
  def run(self):
    print("Running......")


class Athlete(Walker , Runner):
  def __init__(self,training_hours):
    self.training_hours = training_hours

  def Train(self):
    print(f"Training for {self.training_hours} hours")

athlete = Athlete(5)
athlete.Train()
# Out:
# Training for 5 hours

# %%
class A:
  def show(self):
    print("A's show method")

class B(A):
  def show(self):
    print("B's show method")

class C(A):
  def show(self):
    print("C's show method")

class D(B , C):
  pass

d = D()
d.show()
print(D.__mro__)
# Out:
# B's show method
# (<class '__main__.D'>, <class '__main__.B'>, <class '__main__.C'>, <class '__main__.A'>, <class 'object'>)

# %%
## base class
class Shape:
  def __init__(self,color):
    self.color = color

class Circle(Shape):
  def __init__(self , color , radius):
    super().__init__(color)
    self.radius = radius

circle = Circle('Red' , 5)
print(circle.color , circle.radius)
# Out:
# Red 5

# %%
class Person:
  def __init__(self,name):
    self.name = name

class Employee:
  def __init__(self,employee_id):
    self.employee_id = employee_id

class Manager(Person , Employee):
  def __init__(self,name,employee_id):
    super().__init__(name)
    Employee.__init__(self,employee_id)

manager = Manager("John" , "M123")
print(manager.name , manager.employee_id)
# Out:
# John M123

# %%
class Vehicle:
  def start(self):
    print("Vehicle starting..")

class Car(Vehicle):
  def start(self):
    print("Car is starting..")
    super().start()


car = Car()
car.start()
# Out:
# Car is starting..
# Vehicle starting..

# %%
class Flyer:
    def fly(self):
        return "Flying..."

class Swimmer:
    def swim(self):
        return "Swimming..."

class Superhero(Flyer, Swimmer):
    def __init__(self, name):
        self.name = name
        # Optionally call methods here if you want side effects
        super().fly()
        super().swim()

    def __str__(self):
        return f"{self.name} is {self.fly()} and jumped into the water and started {self.swim()}"

hero = Superhero("Batman")
print(hero)
# Out:
# Batman is Flying... and jumped into the water and started to Swimming...

# %%
class Base1:
  def __init__(self ,a):
    self.a = a

class Base2:
  def __init__(self,b):
    self.b = b

class Derived(Base1 , Base2):
  def __init__(self , a , b , c):
    super().__init__(a)
    Base2.__init__(self, b)
    self.c = c

derived = Derived("a" , "b" , "c")
derived.c
# Out:
# 'c'

# %%
class Animal:
  pass
class Cat(Animal):
  pass

animal = Animal()
cat = Cat()
print(isinstance(animal , Animal))
print(isinstance(cat , Animal))
print(isinstance(cat , Cat))
print(isinstance(animal , Cat))
# Out:
# True
# True
# True
# False

# %%
class Bird:
  def speak(self):
    pass

class Parrot(Bird):
  def speak(self):
    print("Parrot syas : Squawk")

class Penguin(Bird):
  def speak(self):
    print("Penguin says : Honk!")


birds = [Parrot(), Penguin()]
for bird in birds:
  bird.speak()
# Out:
# Parrot syas : Squawk
# Penguin says : Honk!

# %%
class Device:
  def __init__(self,brand):
    self.brand = brand

class Phone(Device):
  def __init__(self,brand,model):
    super().__init__(brand)
    self.model = model

class Camera:
  def __init__(self,resolution):
    self.resolution = resolution

class Smartphone(Phone , Camera):
  def __init__(self,brand,model , resolution):
    Phone.__init__(self,brand ,model)
    Camera.__init__(self, resolution)

smartphone = Smartphone('Apple' , 'iPhone 12' , '12 MP')
print(smartphone.brand, smartphone.model , smartphone.resolution)
# Out:
# Apple iPhone 12 12 MP

# %%
class Student:
  def report_Card(self,name , roll_num , marks):
    self.name = name
    self.roll_num = roll_num
    self.marks = marks

    print(f"student name : {self.name} , roll number : {self.roll_num} , marks obntained : {self.marks}")


report = Student()
report.report_Card("siddharth jha" , 123 , 97)
# Out:
# student name : siddharth jha , roll number : 123 , marks obntained : 97

# %%
class Book:
  def discount(self,title,author,price):
    self.title = title
    self.author = author
    self.price = price

    if self.price >= 500:
      actual_price = self.price - 50
      print(f"Actual price after discount is : {actual_price}")

    else:
      print(f"total price : {self.price}")


dis = Book()
dis.discount("ring of fire" , "keppling" , 499)
# Out:
# total price : 499

# %%
from logging import exception
class BankAccount:
  def __init__(self,account_number, balance):
    self.account_number = account_number
    self.balance = balance

  def deposit(self,amount):
    self.balance += amount

  def withdraw(self,amount):
    amount = int(input("Enter the amount : "))
    if self.balance < amount:
      raise InsufficientBalanceError("Insufficient balance")
    else:
      self.balance -= amount


bank = BankAccount("12345" , 50000)
bank.deposit(5000)
bank.withdraw(55002)
# Out:
# Enter the amount : 1200

# %%
class InsufficientBalanceError(Exception):
  pass

class BankAccount:
  def __init__(self,account_number,balance):
    self.__account_number = account_number
    self.__balance = balance

  def Deposit(self , amount):
    self.__balance += amount

  def withdraw(self , amount):
    amount = int(input("Enter the amount to withdraw : "))
    if amount > self.__balance:
      raise InsufficientBalanceError("Insufficient balance")
    else:
      self.__balance -= amount

  def check(self):
    return self.__balance


amount = BankAccount("12345" , 2000)
amount.Deposit(300)
print(amount.check())
try:
  amount.withdraw(amount)
except InsufficientBalanceError as e:
  print(f"Error : {e}")

print(amount.check())
# Out:
# 2300
# Enter the amount to withdraw : 120
# 2180

# %%
class FoodDelivery:
  def __init__(self,in_cart=None, out_of_stock=None):
    self.in_cart = in_cart if in_cart is not None else []
    self.out_of_stock = out_of_stock if out_of_stock is not None else []
    self.order_placed = False
    self.delivered = False

  def add_item(self, item: str):
    if item in self.out_of_stock:
      print(f"Sorry, '{item}' is currently out of stock.")
    else:
      self.in_Cart.append(item)
      print(f"Added '{item}' to cart.")

  def remove_item(self, item: str):
    if item in self.in_cart:
      self.in_cart.remove(item)
      print(f"Removed '{item}' from cart.")
    else:
      print(f"'{item}' is not in your cart.")

  def place_order(self):
    if not self.in_cart:
      print("Cannot place order: Cart is empty!")
    elif self.order_placed:
      print("Order successfully placed already!")
    else:
      self.order_placed = True
      print("Order successfully placed!")

  def mark_delivered(self):
    if not self.order_placed:
      print("Cannot deliver: Order hasn't been placed yet. ")
    elif self.delivered:
      print("order was aleady delivered")
    else:
      self.delivered = True
      print("Order delivered! Enjoy your meal.")

  def get_status(self) -> str:
        """Returns current state of the order."""
        if self.delivered:
            return "Status: Delivered"
        elif self.order_placed:
            return "Status: On the way"
        elif self.in_cart:
            return f"Status: In Cart ({len(self.in_cart)} items)"
        return "Status: Empty Cart"

# %%
class Student:
  def __init__(self, name , Grade  , section , roll_no):
    self.name = name
    self.Grade = Grade
    self.section = section
    self.roll_no = roll_no

  def details(self):
    print(f"Name : {self.name}, grade : {self.Grade} , section : {self.section} , roll no : {self.roll_no}")



s = Student("Siddharth" , 12 , 'B' , 1234)
s.details()
# Out:
# Name : Siddharth, grade : 12 , section : B , roll no : 1234

# %%
class Rectangle:
  def __init__(self , length , breadth):
    self.length = length
    self.breadth = breadth

  def area(self):
    Area = (self.length * self.breadth)
    print(Area)

  def perimeter(self):
    Perimeter = 2 * (self.length + self.breadth)
    print(Perimeter)

rect = Rectangle(12 , 6)
rect.area()
rect.perimeter()
# Out:
# 72
# 36
